# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('transaction-logs-1.csv', delimiter=';', dtype=str)
df2 = pd.read_csv('transaction-logs-2.csv', delimiter=';', dtype=str)
df = pd.concat([df, df2], ignore_index=True)
df = df[['Date created', 'Offer SKU', 'Type', 'Quantity', 'Amount']]
df['Offer SKU'] = df['Offer SKU'].replace(['0004925700', '0004928100', '0004928200', '0004928800', '0004555700', '0004933600'], ['0005346800', '0005347000', '0005346900', '0005347100', '0005310300', '0005347200'])
df.to_csv('Transactions.csv', index=False)
df
# Out:
#                  Date created   Offer SKU              Type Quantity  Amount
# 0       01/01/2024 - 00:37:56  0004934200      Order amount        1   35.54
# 1       01/01/2024 - 00:37:56  0004934200  Shipping charges        1    0.00
# 2       01/01/2024 - 00:37:56  0004934200        Commission        1   -7.11
# 3       01/01/2024 - 00:37:56  0004934200    Commission tax        1   -1.42
# 4       01/01/2024 - 01:54:41  0004934400      Order amount        1   35.54
# ...                       ...         ...               ...      ...     ...
# 515146  10/03/2026 - 23:14:35  0004928500    Commission tax        1   -2.00
# 515147  10/03/2026 - 23:16:16  0005190105      Order amount        1   84.99
# 515148  10/03/2026 - 23:16:16  0005190105  Shipping charges        1    0.00
# 515149  10/03/2026 - 23:16:16  0005190105        Commission        1  -17.00
# 515150  10/03/2026 - 23:16:16  0005190105    Commission tax        1   -3.40
#
# [515151 rows x 5 columns]

# %%
temp = df['Date created'].str.split(' - ', expand=True)
df['Date'] = pd.to_datetime(temp[0], format='%d/%m/%Y')
# Out:
#                  Date created          Date received Transaction Date  \
# 0       01/01/2024 - 00:37:56  19/01/2024 - 04:22:00              NaN
# 1       01/01/2024 - 00:37:56  19/01/2024 - 04:22:00              NaN
# 2       01/01/2024 - 00:37:56  19/01/2024 - 04:22:00              NaN
# 3       01/01/2024 - 00:37:56  19/01/2024 - 04:22:00              NaN
# 4       01/01/2024 - 01:54:41                    NaN              NaN
# ...                       ...                    ...              ...
# 494105  05/02/2026 - 12:42:00                    NaN              NaN
# 494106  05/02/2026 - 12:49:39                    NaN              NaN
# 494107  05/02/2026 - 12:49:39                    NaN              NaN
# 494108  05/02/2026 - 12:49:39                    NaN              NaN
# 494109  05/02/2026 - 12:49:39                    NaN              NaN
#
#                    Shop    Order number Invoice number Transaction Number  \
# 0       Ashwood Leather  DUX025074121-A   000000245981                NaN
# 1       Ashwood Leather  DUX025074121-A   000000245981                NaN
# 2       Ashwood Leather  DUX025074121-A   000000245981                NaN
# 3       Ashwood Leather  DUX025074121-A   000000245981                NaN
# 4       Ashwood Leather  DUX025074868-A   000000245981                NaN
# ...                 ...             ...            ...                ...
# 494105  Ashwood Leather  DUX051502105-A            NaN                NaN
# 494106  Ashwood Leather  DUX051502331-A            NaN                NaN
# 494107  Ashwood Leather  DUX051502331-A            NaN                NaN
# 494108  Ashwood Leather  DUX051502331-A            NaN                NaN
# 494109  Ashwood Leather  DUX051502331-A            NaN                NaN
#
#        Quantity        Category Label   Offer SKU  ...    Balance Currency  \
# 0             1  Womens Bags & Purses  0004934200  ...  110823.20      GBP
# 1             1  Womens Bags & Purses  0004934200  ...  110823.20      GBP
# 2             1  Womens Bags & Purses  0004934200  ...  110816.09      GBP
# 3             1  Womens Bags & Purses  0004934200  ...  110814.67      GBP
# 4             1  Womens Bags & Purses  0004934400  ...  110850.21      GBP
# ...         ...                   ...         ...  ...        ...      ...
# 494105        1  Womens Bags & Purses  0004930900  ...  312707.14      GBP
# 494106        1  Womens Bags & Purses  0005433500  ...  312745.13      GBP
# 494107        1  Womens Bags & Purses  0005433500  ...  312745.13      GBP
# 494108        1  Womens Bags & Purses  0005433500  ...  312737.53      GBP
# 494109        1  Womens Bags & Purses  0005433500  ...  312736.01      GBP
#
#        Customer order reference Shop order reference     Billing cycle date  \
# 0                           NaN                  NaN  27/01/2024 - 00:48:35
# 1                           NaN                  NaN  27/01/2024 - 00:48:35
# 2                           NaN                  NaN  27/01/2024 - 00:48:35
# 3                           NaN                  NaN  27/01/2024 - 00:48:35
# 4                           NaN                  NaN  27/01/2024 - 00:48:35
# ...                         ...                  ...                    ...
# 494105                      NaN                  NaN                    NaN
# 494106                      NaN                  NaN                    NaN
# 494107                      NaN                  NaN                    NaN
# 494108                      NaN                  NaN                    NaN
# 494109                      NaN                  NaN                    NaN
#
#        Shop ID     Order line ID Refund ID    Sales channel       Date
# 0         2472  DUX025074121-A-1       NaN              NaN 2024-01-01
# 1         2472  DUX025074121-A-1       NaN              NaN 2024-01-01
# 2         2472  DUX025074121-A-1       NaN              NaN 2024-01-01
# 3         2472  DUX025074121-A-1       NaN              NaN 2024-01-01
# 4         2472  DUX025074868-A-1       NaN              NaN 2024-01-01
# ...        ...               ...       ...              ...        ...
# 494105    2472  DUX051502105-A-1       NaN  Initial Channel 2026-02-05
# 494106    2472  DUX051502331-A-1       NaN  Initial Channel 2026-02-05
# 494107    2472  DUX051502331-A-1       NaN  Initial Channel 2026-02-05
# 494108    2472  DUX051502331-A-1       NaN  Initial Channel 2026-02-05
# 494109    2472  DUX051502331-A-1       NaN  Initial Channel 2026-02-05
#
# [494110 rows x 27 columns]

# %%
style = pd.read_csv('Style Listing Stock.csv', dtype=str, skiprows=2)
style = style[~style['Style'].isna()]
style = style[style['Style'] != 'Style']
style = style[~style['Category'].isna()]
style = style[['Style', 'Category', 'Department']]
style.head(2)
# Out:
#    Style Category   Department
# 0    007   GLOVES       LADIES
# 16  010B     HATS  LEATHER CAP

# %%
fe = pd.read_csv('Fashione EAN 04-02-26.csv', dtype=str)
fe['Offer SKU'] = fe['PLU']
fe = pd.merge(fe, style, on='Style', how='left')
fe = fe[['Offer SKU', 'Style', 'Colour', 'Size', 'Category']]
fe['Category'] = fe['Category'].fillna('OTHER')
fe.head()
# Out:
#     Offer SKU Style      Colour Size Category
# 0  0002875800   007    BLK/BLUE    S   GLOVES
# 1  0002875801   007    BLK/BLUE    M   GLOVES
# 2  0002875802   007    BLK/BLUE    L   GLOVES
# 3  0002875803   007    BLK/BLUE   XL   GLOVES
# 4  0002876200   007  BLK/PURPLE    S   GLOVES

# %%
df = df[['Offer SKU', 'Type', 'Quantity', 'Amount']]
df = pd.merge(df, fe, on='Offer SKU', how='left')

# %%
df
# Out:
#          Offer SKU              Type Quantity Amount   Style      Colour  \
# 0       0004934200      Order amount        1  35.54   63753    MANDARIN
# 1       0004934200  Shipping charges        1   0.00   63753    MANDARIN
# 2       0004934200        Commission        1  -7.11   63753    MANDARIN
# 3       0004934200    Commission tax        1  -1.42   63753    MANDARIN
# 4       0004934400      Order amount        1  35.54   63753     parafin
# ...            ...               ...      ...    ...     ...         ...
# 494105  0004930900    Commission tax        1  -2.20   64198  2 tone tan
# 494106  0005433500      Order amount        1  37.99  oxford       BLACK
# 494107  0005433500  Shipping charges        1   0.00  oxford       BLACK
# 494108  0005433500        Commission        1  -7.60  oxford       BLACK
# 494109  0005433500    Commission tax        1  -1.52  oxford       BLACK
#
#             Size  Category
# 0       ONE SIZE  HANDBAGS
# 1       ONE SIZE  HANDBAGS
# 2       ONE SIZE  HANDBAGS
# 3       ONE SIZE  HANDBAGS
# 4       ONE SIZE  HANDBAGS
# ...          ...       ...
# 494105  ONE SIZE  HANDBAGS
# 494106  ONE SIZE  HANDBAGS
# 494107  ONE SIZE  HANDBAGS
# 494108  ONE SIZE  HANDBAGS
# 494109  ONE SIZE  HANDBAGS
#
# [494110 rows x 8 columns]

# %%
# Out:
# Type
# Order amount              107463
# Shipping charges          107463
# Commission                107463
# Commission tax            107463
# Order amount refund        15656
# Shipping charge refund     15656
# Commission refund          15656
# Commission tax refund      15656
# Manual invoice               768
# Manual invoice tax           768
# Payment                       40
# Subscription fee              24
# Subscription tax              24
# Manual credit                  5
# Manual credit tax              5
# Name: count, dtype: int64

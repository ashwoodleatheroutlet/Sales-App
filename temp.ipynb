# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('transaction-logs (76).csv', delimiter=';', dtype=str)
df = df[['Date created', 'Offer SKU', 'Type', 'Quantity', 'Amount']]
df['Offer SKU'] = df['Offer SKU'].replace(['0004925700', '0004928100', '0004928200', '0004928800', '0004555700', '0004933600'], ['0005346800', '0005347000', '0005346900', '0005347100', '0005310300', '0005347200'])

df = df[(df['Type'] == 'Order amount') | (df['Type'] == 'Order amount refund')]
df.to_csv('Transactions.csv', index=False)
df
# Out:
#                  Date created   Offer SKU          Type Quantity  Amount
# 0       01/01/2025 - 00:04:37  0005203800  Order amount        1   27.19
# 4       01/01/2025 - 00:11:24  0005254604  Order amount        1  198.74
# 8       01/01/2025 - 00:12:20  0001606602  Order amount        1  119.69
# 12      01/01/2025 - 00:14:37  0005384600  Order amount        1   29.99
# 16      01/01/2025 - 00:14:37  0005292600  Order amount        1   31.19
# ...                       ...         ...           ...      ...     ...
# 363369  11/05/2026 - 11:11:31  0005448600  Order amount        1   49.99
# 363373  11/05/2026 - 11:11:31  0004926500  Order amount        1   54.99
# 363377  11/05/2026 - 11:18:12  0004882106  Order amount        1  149.25
# 363381  11/05/2026 - 11:18:52  0005190104  Order amount        1   89.99
# 363385  11/05/2026 - 11:25:31  0004882102  Order amount        1  149.25
#
# [90145 rows x 5 columns]

# %%
temp = df['Date created'].str.split(' - ', expand=True)
df['Date'] = pd.to_datetime(temp[0], format='%d/%m/%Y')

# %%
style = pd.read_csv('Style Listing Stock.csv', dtype=str, skiprows=2)
style = style[~style['Style'].isna()]
style = style[style['Style'] != 'Style']
style = style[~style['Category'].isna()]
style = style[['Style', 'Category', 'Department']]
style.head(2)
# Out:
#    Style Category   Department
# 0    007   GLOVES       LADIES
# 13  010B     HATS  LEATHER CAP

# %%
fe = pd.read_csv('Fashione-EAN 07-05-2026.csv', dtype=str)
fe['Offer SKU'] = fe['PLU']
fe = pd.merge(fe, style, on='Style', how='left')
fe = fe[['Offer SKU', 'Style', 'Colour', 'Size', 'Category']]
fe['Category'] = fe['Category'].fillna('OTHER')
fe.head()
# Out:
#     Offer SKU Style      Colour Size Category
# 0  0002875800   007    BLK/BLUE    S   GLOVES
# 1  0002875801   007    BLK/BLUE    M   GLOVES
# 2  0002875802   007    BLK/BLUE    L   GLOVES
# 3  0002875803   007    BLK/BLUE   XL   GLOVES
# 4  0002876200   007  BLK/PURPLE    S   GLOVES

# %%
df = df[['Offer SKU', 'Type', 'Quantity', 'Amount']]
df = pd.merge(df, fe, on='Offer SKU', how='left')

# %%
df
# Out:
#          Offer SKU          Type Quantity  Amount     Style      Colour  \
# 0       0004934200  Order amount        1   35.54     63753    MANDARIN
# 1       0004934400  Order amount        1   35.54     63753     parafin
# 2       0004928000  Order amount        1   56.24     62879  light wine
# 3       0004475000  Order amount        1   53.99     63789       BLACK
# 4       0004473500  Order amount        1   49.49       NaN         NaN
# ...            ...           ...      ...     ...       ...         ...
# 134437  0004934400  Order amount        1   34.99     63753     parafin
# 134438  0004933900  Order amount        1   34.99     63753       BLACK
# 134439  0005213905  Order amount        1  129.99  AWL-1282       BLACK
# 134440  0000851400  Order amount        1   19.99       TAB       BLACK
# 134441  0005169800  Order amount        1   34.99     64397       BLACK
#
#             Size        Category
# 0       ONE SIZE        HANDBAGS
# 1       ONE SIZE        HANDBAGS
# 2            NaN        HANDBAGS
# 3       ONE SIZE        HANDBAGS
# 4            NaN             NaN
# ...          ...             ...
# 134437  ONE SIZE        HANDBAGS
# 134438  ONE SIZE        HANDBAGS
# 134439        16  LADIES JACKETS
# 134440       NaN        HANDBAGS
# 134441  ONE SIZE        HANDBAGS
#
# [134442 rows x 8 columns]
